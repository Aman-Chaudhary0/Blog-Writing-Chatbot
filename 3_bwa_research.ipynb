# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_tavily import TavilySearch

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
llm = ChatOllama(model="qwen3:1.7b")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily) 
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:

    tool = TavilySearch(max_results=max_results)
    result = tool.invoke({"query": query})

    print("\n========== TAVILY DEBUG ==========")
    print("Result type:", type(result))
    print("Result:", result)
    print("==================================\n")

    normalized: List[dict] = []

    # Tavily normally returns a dictionary containing "results"
    if isinstance(result, dict):
        results = result.get("results", [])

    # Safety fallback
    elif isinstance(result, list):
        results = result

    else:
        results = []

    for r in results:
        if not isinstance(r, dict):
            print("Skipping non-dict result:", r)
            continue

        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": (
                    r.get("published_date")
                    or r.get("published_at")
                ),
                "source": r.get("source"),
            }
        )

    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = "".join(
    c if c.isalnum() or c in (" ", "_", "-") else ""
    for c in plan.blog_title
)
    filename = filename.strip().lower().replace(" ", "_") + ".md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str):
    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "sections": [],
            "final": "",
        }
    )

    return out

# %%
#run("Write a blog on Open Source LLMs in 2026")
run("State of Multimodal LLMs in 2026")
# Out:
# ========== TAVILY DEBUG ==========
# Result type: <class 'dict'>
# Result: {'query': 'What are the key advancements in multimodal LLMs for 2026? (2026)', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://sesamedisk.com/last-six-months-llms-advances-2026', 'title': 'Last Six Months of LLM Advancements in 2026 - Sesame Disk', 'content': 'Key Takeaways:\n\n LLMs in 2026 emphasize multimodal understanding, autonomous agents, and domain-specific expertise.\n Hyperscaler AI infrastructure spending is shifting focus from training to inference and cost efficiency.\n OpenAI’s GPT-5.5 leads in reasoning and coding prf, setting industry standards.\n Safety, transparency, and regulatory compliance are central to deployment strategies.\n Open-source AI projects continue to democratize access and foster innovation.\n\n## Sources and References [...] ## Summary\n\nThe last six months have been transformative for large language models in 2026. Breakthroughs in multimodal capability, autonomous reasoning, and domain specialization have expanded AI’s practical impact. Infrastructure spending by hyperscalers reflects shift to sustained inference workloads, emphasizing efficiency and scalability. Safety, transparency, and bias mitigation are integral to deployment, meeting both regulatory demands and user expectations. [...] Robustness and Reliability: Efforts to reduce hallucinations and improve factual accuracy will shape user trust and adoption.\n Expanded Multimodal Integration: Combining text, images, audio, and video inputs will create richer interaction paradigms.\n Open-Source Growth: Expect continued growth in open-source LLM projects that enable customization and regional adaptation.', 'score': 0.9541759, 'raw_content': None, 'id': '96858c-00'}, {'url': 'https://www.youtube.com/watch?v=_WYiaeLwfeQ', 'title': 'The Real Frontier of AI (2026): Agents, Multimodal Models ...', 'content': "of like structural optimization. As of 2026, large language models have made key advances. They can handle massive context windows, often in the millions of tokens, and they've improved in reasoning, tool use, and multimodal capabilities like combining text and images. Open source models are also more mature and cost effective. However, we still don't have general purpose AI and scaling brings high costs and complexity. So, while LLMs are more powerful, success now depends on how well they're", 'score': 0.8989177, 'raw_content': None, 'id': '22936e-01'}, {'url': 'https://zylos.ai/research/2026-01-13-multimodal-ai-vision-language-models', 'title': 'Multimodal AI and Vision-Language Models 2026', 'content': '2026 Advances:\n\n Multimodal agents reason across vision, audio, and text simultaneously\n Real-time processing enables responsive robotic behaviors\n Edge deployment critical for latency-sensitive applications\n\n### 4.6 Enterprise Search and Knowledge Management\n\nCapabilities: [...] Performance Gains:\n\n Outperforms SigLIP at all model scales\n Improved zero-shot classification\n Better image-text retrieval\n Enhanced visual representations for VLMs\n Significant gains on localization tasks\n\n### 2.3 Integration with LLMs\n\nCommon Architecture Pattern:\n\n```\nImage Input → Vision Encoder (SigLIP/CLIP) → Vision-Language Adapter → LLM → Output \n```\n\nReal-World Implementations: [...] 2026 Status:\n\n Multimodal search becoming standard in enterprise platforms\n Reduces "content is there but can\'t find it" problem\n Improves employee productivity and knowledge sharing\n\n### 4.7 Content Creation and Marketing\n\nCapabilities:\n\n Image analysis for content strategy\n Visual trend identification\n Brand consistency checking\n Product catalog enhancement\n Visual content recommendation\n\nApplications:', 'score': 0.882276, 'raw_content': None, 'id': '4916b3-02'}, {'url': 'https://intl.cloud.baidu.com/en/article/8763002', 'title': '2026 Open-Source LLM Breakthroughs: How Multimodality and Long-Context Capabilities Reshape Application Ecosystems', 'content': 'Sep 82 views\n\nThi ...
# ==================================
#
#
# ========== TAVILY DEBUG ==========
# Result type: <class 'dict'>
# Result: {'query': 'How will multimodal LLMs address the gap between vision and language understanding? (2026)', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.mdpi.com/2079-3197/14/6/125', 'title': 'A Comprehensive Survey and Guide to Multimodal Large Language ...', 'content': 'Much vision–language training data is English-centric, and many evaluation benchmarks assume English captions and questions. This creates a significant gap in MLLM capabilities for non-English languages, particularly low-resource ones. Beyond simply building multilingual benchmarks, future work must address the alignment of visual concepts across cultures—for instance, the visual representation of “breakfast” differs fundamentally between East Asian and Western contexts, and a model trained [...] The advancements in MLLMs have expanded their applications across diverse domains, offering solutions to various real-world problems by bridging the gap between visual data and language. [...] ### 2.5. Cross-Modal Understanding and Visual Reasoning\n\nCross-modal understanding—the ability to jointly reason over visual and textual information—is a defining capability of MLLMs and distinguishes them from unimodal language or vision models. This capability underpins a range of downstream tasks, including visual question answering (VQA), image captioning, visual grounding, cross-modal retrieval, and multimodal dialogue.', 'score': 0.69024646, 'raw_content': None, 'id': 'e23762-00'}, {'url': 'https://www.frontiersin.org/journals/systems-neuroscience/articles/10.3389/fnsys.2025.1683133/full', 'title': 'Will multimodal large language models ever achieve deep ...', 'content': '## 3 State-of-the-art multimodal LLMs\n\nCompared to LLM, the MLLMs process multiple modalities (text, images, audio, video, and structured data). They are trained to integrate knowledge from multiple sources and often perform very well in tasks such as visual question answering, caption generation, and cross-modal retrieval (Ge et al., 2024). Models that integrate only vision and language are called VLM and are used in tasks without motor modality (Wu et al., 2024). [...] Despite impressive performance in various tasks, large language models (LLMs) are subject to the symbol grounding problem, so from the cognitive science perspective, one can argue that they are merely statistics-driven distributional models without a deeper understanding. Modern multimodal versions of LLMs (MLLMs) are trying to avoid this problem by linking language knowledge with other modalities such as vision (Vision Language Models called VLM) or action (Vision Language Action Models called [...] On the other hand, given that the progress in MLLMs is very fast, it may be that improved models will be appearing in forthcoming years, narrowing the gap toward understanding. On that path, it will definitely be inevitable to go beyond learning statistical correlations to reveal causal mechanisms. This will clearly involve a stronger role for the motor modality that facilitates this process in the context of affecting the world. Maybe the well functioning MLLMs would not be body-agnostic but', 'score': 0.6296157, 'raw_content': None, 'id': 'e0724b-01'}, {'url': 'https://www.preprints.org/manuscript/202510.2511', 'title': 'A Review of Multimodal Vision–Language Models: Foundations, Applications, and Future Directions', 'content': 'In April 2023, researchers at the Alibaba DAMO Academy introduced mPLUG-OWL, an open-source multimodal large language model (MM-LLM) designed to address key shortcomings in existing two-stage training strategies. Previous MM-LLMs typically relied on fully frozen visual backbones during both pretraining and instruction-tuning phases, which limited the flexibility of cross-modal alignment. To overcome this, mPLUG-OWL proposed a more adaptive approach—retaining trainable visual components in the [...] This review focuses on LLMs with particular attention to visual ...
# ==================================
#
#
# ========== TAVILY DEBUG ==========
# Result type: <class 'dict'>
# Result: {'query': 'What are the main challenges in deploying multimodal LLMs in real-world applications? (2026)', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.preprints.org/manuscript/202512.1986', 'title': 'Addressing Challenges in Multimodal Large Language ...', 'content': 'alignment, missing modalities, computational efficiency, bias, fairness, interpretability, and generalization . As the field continues to evolve, addressing these open issues will be crucial to unlocking the full potential of MLLMs and ensuring that they can be deployed safely, effectively, and equitably in real-world applications. The solutions to these challenges will likely involve a combination of novel algorithms, better data management strategies, and more robust evaluation frameworks, as [...] While the field of Multimodal Large Language Models (MLLMs) has made remarkable progress in recent years, there remain several critical challenges and open issues that must be addressed to further advance the technology and make it more effective, scalable, and generalizable across a range of real-world applications. These challenges span various aspects of model design, training, data, and deployment, and require deep research into new methodologies, frameworks, and approaches to overcome the [...] of modalities can fluctuate. The computational cost of training and deploying MLLMs is another major hurdle. The training process for these models is extremely resource-intensive due to the large number of parameters involved, the need for multimodal data, and the complexity of processing and fusing multiple modalities simultaneously . Transformer-based architectures, which are commonly used for MLLMs, are notorious for their quadratic complexity with respect to the sequence length, making them', 'score': 0.86080295, 'raw_content': None, 'id': '982f1b-00'}, {'url': 'https://www.youtube.com/watch?v=_WYiaeLwfeQ&xstg=CAMSBhUD_LL2Hw%3D%3D', 'title': 'The Real Frontier of AI (2026): Agents, Multimodal Models, and ...', 'content': "[13:15] dynamically, and scale up or down as needed. There's been progress in how they communicate through shared memory or messaging, and agents can be spun up on demand. However, challenges remain.\n[13:26] Coordination gets complex at scale, full autonomy is still out of reach, and governance is an ongoing issue. Emerging protocols and enterprise deployments are also shaping the field.\n[13:40] So governance and context management and then uh is uh is a is a crux of the problem right now. [...] We break down how modern AI agents coordinate through shared memory, embeddings, vector databases, and orchestration layers, enabling autonomous task planning, tool use, and multi-step reasoning. We also examine why context management, governance, agent orchestration, and scalable multi-agent architecture are becoming the core engineering challenges in advanced AI systems, often more critical than improvements in the underlying LLM models themselves. [...] [7:45] talking between agents through their their inner communication.\n[7:52] Yes, that's spot on. They either pull what they need from shared memory or directly exchange messages in real time.\n[7:58] The design depends on the system. Some rely more on centralized memory. Others use agentto agent messaging. But either way they coordinate to sale.\n[8:11] So I think last year I I think one of the challenges is architecture of multi- aent orchestration.", 'score': 0.72605723, 'raw_content': None, 'id': '1e0cdc-01'}, {'url': 'https://arxiv.org/html/2503.04596v2', 'title': 'LLM Applications: Current Paradigms and the Next Frontier', 'content': '#### 2.3.4. Challenges & Open Problems\n\nWhile self-hosted LLM services provide transparency, customizability, and stronger data control, their practical deployment is far from trivial. Current research and real-world adoption reveal that these systems face persistent efficiency bottlenecks, engineering complexi ...
# ==================================
#
#
# ========== TAVILY DEBUG ==========
# Result type: <class 'dict'>
# Result: {'query': 'Which multimodal LLMs are expected to dominate in 2026? (2026)', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://blog.doshby.com/the-best-large-language-models-llms-in-2026', 'title': 'The Best Large Language Models (LLMs) in 2026 - Doshby Blog', 'content': 'This guide explores the best LLMs in 2026 based on recent benchmarks, enterprise adoption, multimodal capabilities, developer sentiment, pricing efficiency, and overall market influence.\n\n## 1. OpenAI GPT-5 & the O-Series Models\n\nOpenAI remains the dominant force in the LLM industry in 2026. While ChatGPT originally made OpenAI famous, the company’s newer GPT-5 and reasoning-focused o-series models have pushed the frontier much further. [...] ## 2. Anthropic Claude Opus 4.6\n\nAnthropic has quietly become one of the most respected AI companies among developers, researchers, and enterprises.\n\nWhile OpenAI dominates mainstream awareness, Claude models are increasingly viewed as the strongest reasoning-focused LLMs available today. Multiple recent comparisons place Claude Opus 4.6 among the top-performing models for deep analysis, coding workflows, technical documentation, and long-context reasoning. [...] One major differentiator is multilingual intelligence. Mistral performs exceptionally well across European and regional languages, making it highly attractive for international deployments. The company has also expanded into multimodal systems through Pixtral models capable of understanding documents, images, and charts.\n\nMistral’s rapid growth demonstrates that the future of frontier AI is no longer limited to Silicon Valley alone.\n\n## 7. Alibaba Qwen 3.5', 'score': 0.9294982, 'raw_content': None, 'id': 'aa854b-00'}, {'url': 'https://zylos.ai/research/2026-01-13-multimodal-ai-vision-language-models', 'title': 'Multimodal AI and Vision-Language Models 2026', 'content': 'Market Leaders:\n\n GPT-5.2 leads in multimodal understanding (84.2% MMMU) and abstract reasoning (52.9% ARC-AGI-2)\n Claude Opus 4.5 dominates coding tasks (80.9% SWE-bench) with advanced "computer use" capabilities\n Gemini 3 Pro excels in native multimodal processing with 1M token context and 100% AIME 2025 score\n Qwen3-VL-235B rivals proprietary models with 256K context (expandable to 1M) and strong open-source performance\n\nTechnical Evolution: [...] GPT-5.2 leads in general multimodal reasoning\n Claude Opus 4.5 dominates coding and computer use\n Gemini 3 Pro excels in long-context and native multimodal processing\n Qwen3-VL offers best-in-class open-source document understanding\n Task-specific selection critical for optimal performance and cost\n\nTechnical Architecture Maturity: [...] | Model | Parameters | MMMU Score | Best For | Deployment |\n ---  --- \n| GPT-5.2 | ~1T+ (est.) | 84.2% | General multimodal reasoning | Cloud API |\n| Claude Opus 4.5 | Undisclosed | 77.8% | Coding, computer use | Cloud API |\n| Gemini 3 Pro | Undisclosed | ~82% (est.) | Long context, native multimodal | Cloud API |\n| Qwen3-VL-235B | 235B | ~70% | Enterprise, document processing | Self-hosted/Cloud |\n| InternVL3-78B | 78B | 72.2% | Open-source, multi-format | Self-hosted |', 'score': 0.85538095, 'raw_content': None, 'id': 'fd6287-01'}, {'url': 'https://aimlapi.com/blog/best-llms-for-long-context-multimodal-tasks-in-2026', 'title': 'Best LLMs for Long-Context & Multimodal Tasks in 2026', 'content': '| Qwen3-Coder-480B | Alibaba | 256K | — | ~79% | Varies | Varies | API / OW |\n| Claude Sonnet 4.6 | Anthropic | 200K | ~85% | ~75% | $3.00 | $15.00 | API | [...] foundation, Qwen3-Coder-480B is the current benchmark to beat in the open-weight tier. [...] ## Long-Context Leaders\n\n#### `#1 Extreme Context`\n\n### Llama 4 Scout — 10M tokens', 'score': 0.81524754, 'raw_content': None, 'id': 'feae8e-02'}, {'url': 'https://www.youtube.com/watch?v=_WYiaeLwfeQ', 'title': 'The Real Frontier of AI (2026): Agents, Multimodal Models ...', 'content': "Artifici ...
# ==================================
#
#
# ========== TAVILY DEBUG ==========
# Result type: <class 'dict'>
# Result: {'query': 'What are the ethical considerations for multimodal LLMs in 2026? (2026)', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://gaper.io/ethical-considerations-llm-development', 'title': 'Ethical Considerations in LLM Development - Gaper.io', 'content': 'The ethical considerations in LLM development that decide whether a product ships safely in 2026 are bias control, hallucination guardrails, data provenance, copyright clearance, privacy handling, transparency disclosures, and red-team coverage. Each one has a hard regulatory deadline attached.\n\n### Key Takeaways [...] LLMs & RAG\n\n# Ethical Considerations in LLM Development\n\nThe 2026 operator playbook for LLM ethics: bias control, hallucination guardrails, data provenance, privacy, and red-teaming.\n\nBy Mustafa Najoom»Updated Aug 17, 2026»14 min read»ethical considerations llm development\n\nEthical Considerations in LLM Development\n\n## Ethical considerations in LLM development: the 2026 operator playbook [...] Every team shipping a customer-facing LLM in 2026 is now a few ethical considerations in LLM development away from a brand crisis or a regulatory fine. The EU AI Act’s general-purpose model obligations went enforceable in August 2025. The US Executive Order on AI requires red-team reporting above the compute threshold. The FTC has opened formal inquiries into seven major model providers. The cost of being wrong is no longer hypothetical.', 'score': 0.8773195, 'raw_content': None, 'id': 'f9c8bd-00'}, {'url': 'https://www.frontiersin.org/journals/digital-health/articles/10.3389/fdgth.2026.1736616/full', 'title': 'Frontiers | Through the looking glass: ethical considerations regarding LLM-induced hallucinations to medical questions', 'content': '20.\n\nWorld Health Organization. Ethics and Governance of Artificial Intelligence for Health: Large Multi-modal models. wHO Guidance. Geneva: World Health Organization (2024). Available online at: (Accessed January 14, 2026)\n\n21.\n\nLekadirKFrangiAFPorrasARGlockerBCintasCLanglotzCPet alFUTURE-AI: international consensus guideline for trustworthy and deployable artificial intelligence in healthcare. Br Med J. (2025) 388:e081554. 10.1136/bmj-2024-081554\n\n22. [...] Keywords\n\nartificial intelligence, dynamic framework, ethical accountability, ethics, hallucinations\n\nCitation\n\nKozlakidis Z, Wootton T and Mayrhofer MT (2026) Through the looking glass: ethical considerations regarding LLM-induced hallucinations to medical questions. Front. Digit. Health 8:1736616. doi: 10.3389/fdgth.2026.1736616\n\nReceived\n\n31 October 2025\n\nRevised\n\n14 January 2026\n\nAccepted\n\n15 January 2026\n\nPublished\n\n13 March 2026\n\nVolume\n\n8 - 2026\n\nEdited by [...] Deployers—Institutions and platforms integrating LLMs into health systems have the ethical imperative to ensure (as with any equipment or software) that contextual validation, risk assessment, and alignment with clinical standards take place to pre-defined local and national standards (8). Furthermore, the implementation of such systems touches the principle of fairness, so that any improvements in patient service are as equitable as possible.', 'score': 0.7382357, 'raw_content': None, 'id': '82a9c2-01'}, {'url': 'https://uniathena.com/prompt-engineering-guide-mastering-multimodal-llms', 'title': 'Prompt Engineering Guide for 2026: Mastering Multimodal ...', 'content': 'FIG 5: Advanced Prompting Techniques 2026\n\n## Academic and Ethical Considerations\n\nEthical prompt engineering is fundamental to responsible AI practice. Transparency through proper citation and credible references not only strengthens accuracy but also builds trust in AI-generated content. Prompts should be thoughtfully structured to minimize bias, encourage clear reasoning, and ensure that outputs remain fair, explainable, and academically sound.\n\n## Conclusion [...] Introduction\n Key Takeaways\n What Is Prompt Engineering?\n Quick Definition ...
# ==================================
# {'topic': 'State of Multimodal LLMs in 2026',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['What are the key advancements in multimodal LLMs for 2026? (2026)',
#   'How will multimodal LLMs address the gap between vision and language understanding? (2026)',
#   'What are the main challenges in deploying multimodal LLMs in real-world applications? (2026)',
#   'Which multimodal LLMs are expected to dominate in 2026? (2026)',
#   'What are the ethical considerations for multimodal LLMs in 2026? (2026)'],
#  'evidence': [EvidenceItem(title='Ethical Considerations in LLMs: Regulatory and Technical Frameworks', url='https://www.example.com/ethics-llms-regulation', published_at=None, snippet='The EU AI Act (2024) mandates bias control, hallucination guardrails, and data provenance for AI systems. The US Executive Order 2026 sets a 2026 deadline for operator guidelines, emphasizing transparency and red-team coverage.', source=None),
#   EvidenceItem(title='LLM Ethical Playbook (2026)', url='https://www.example.com/llm-playbook', published_at=None, snippet='Focuses on bias control, hallucination guardrails, data provenance, privacy, and red-teaming. Highlights the cost of being wrong as no longer hypothetical, stressing the need for operational rigor.', source=None),
#   EvidenceItem(title='Ethical Considerations in LLM-Induced Hallucinations (Healthcare)', url='https://www.frontiersin.org/articles/10.3389/fdih.2024.1352886', published_at=None, snippet='Emphasizes contextual validation, fairness, and alignment with clinical standards. Highlights the need for WHO guidance to address risks in medical question-answering systems.', source=None),
#   EvidenceItem(title='Prompt Engineering for Ethical AI', url='https://www.uniatech.com/prompt-engineering-guide', published_at=None, snippet='Highlights ethical prompt engineering, transparency, minimizing bias, and explainability. Provides tips for structuring prompts and avoiding vague instructions.', source=None),
#   EvidenceItem(title='Privacy and Data Usage in LLMs', url='https://www.computer.org/portal/content/2024/privacy-llms', published_at=None, snippet='Emphasizes consent, data privacy, and potential bias in LLMs. Notes the need for robust privacy frameworks to prevent misuse of sensitive data.', source=None),
#   EvidenceItem(title='Agentic AI and Multi-Agent Systems', url='https://www.youtube.com/watch?v=example_video_id', published_at=None, snippet='Discusses governance, context management, and orchestration in agentic AI. Highlights the need for alignment and coordination in multi-agent systems.', source=None),
#   EvidenceItem(title='Multimodal LLMs and Integration', url='https://www.acm.org/2024/multimodal-llms', published_at=None, snippet='Focuses on architectural and system-level approaches for multimodal LLMs. Highlights challenges in cross-modal grounding and integration of diverse modalities.', source=None)],
#  'plan': Plan(blog_title='State of Multimodal LLMs in 2026: Ethical, Architectural, and Operational Considerations', audience='Developers and AI researchers', tone='Informative, analytical, and forward-looking', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Context and Ethical Foundations', goal='Provide a foundational understanding of the regulatory landscape and ethical priorities shaping multimodal LLMs in 2026.', bullets=['The EU AI Act (2024) mandates bias control, hallucination guardrails, and data provenance for AI systems.', 'The US Executive Order 2026 sets a 2026 deadline for operator guidelines, emphasizing transparency and red-team coverage.', 'Ethical frameworks like the LLM Ethical Playbook highlight the need for operational rigor in mitigating bias and hallucinations.'], target_words=150, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Ethical Considerations in Multimodal LLMs', goal='Examine key ethical challenges, including bias, privacy, and hallucination mitigation in multimodal systems.', bullets=['Bias control and fairness are critical for ensuring equitable outcomes in multimodal LLMs.', 'Privacy frameworks must address data consent and potential bias in sensitive modalities (e.g., medical or financial data).', 'Red-team coverage and contextual validation are essential for verifying the reliability of multimodal outputs.'], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Architectural and System-Level Challenges', goal='Outline the technical hurdles in integrating diverse modalities (text, audio, video) into a cohesive LLM architecture.', bullets=['Cross-modal grounding requires alignment of semantic representations across modalities.', 'System-level challenges include optimizing for computational efficiency and memory usage.', 'Agentic AI frameworks must ensure coordination and alignment between multi-agent systems.'], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Performance and Cost Considerations', goal='Analyze resource allocation, training costs, and optimization strategies for multimodal LLMs.', bullets=['Multimodal LLMs require higher computational resources due to cross-modal processing.', 'Training costs scale with the number of modalities and the complexity of integration.', 'Optimization techniques like quantization and pruning are critical for reducing latency and energy consumption.'], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Security and Privacy Frameworks', goal='Discuss data privacy, consent mechanisms, and the role of privacy-preserving techniques in multimodal LLMs.', bullets=['Privacy frameworks must ensure compliance with regulations like GDPR and the EU AI Act.', 'Anonymization and differential privacy are vital for protecting sensitive data in multimodal systems.', 'Secure multi-party computation and homomorphic encryption are emerging solutions for privacy preservation.'], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=6, title='Debugging and Observability', goal='Provide actionable strategies for debugging, monitoring, and observability in multimodal LLMs.', bullets=['Implement logging and metrics to track multimodal input/output consistency.', 'Use distributed tracing for monitoring cross-modal processing pipelines.', 'Leverage anomaly detection to identify hallucinations or bias in multimodal outputs.'], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=7, title='Future Trends and Implications', goal='Summarize key trends and their implications for the evolution of multimodal LLMs.', bullets=['The integration of multimodal data will require evolving training paradigms and evalua ...
#  'sections': [(1,
#    '## Context and Ethical Foundations  \n\nThe development of multimodal Large Language Models (LLMs) in 2026 is increasingly shaped by regulatory frameworks and ethical priorities, with the EU AI Act (2024) and the US Executive Order 2026 setting critical benchmarks for transparency, bias mitigation, and data governance. The EU AI Act mandates that AI systems, including multimodal models, must include mechanisms to control bias, prevent hallucinations, and ensure data provenance, reflecting a global shift toward accountability in AI deployment. Meanwhile, the US Executive Order 2026 establishes a 2026 deadline for operator guidelines, emphasizing transparency in model behavior and the inclusion of red-team coverage to identify and mitigate vulnerabilities.  \n\nEthical frameworks such as the LLM Ethical Playbook highlight the necessity of operational rigor in addressing bias and hallucinations, emphasizing the importance of prompt engineering, data diversity, and continuous validation. These priorities underscore the growing recognition that multimodal LLMs must not only meet technical performance goals but also align with societal values, ensuring fairness, privacy, and trust in AI systems. As the field matures, the interplay between regulatory requirements and ethical design will continue to define the trajectory of multimodal LLMs in 2026.'),
#   (2,
#    '## Ethical Considerations in Multimodal LLMs  \nMultimodal large language models (LLMs) face critical ethical challenges, including bias, privacy, and hallucination mitigation. Bias control is essential to ensure equitable outcomes, as models may inherit biases from training data, leading to unfair results in sensitive modalities like healthcare or finance. Privacy frameworks must address data consent and potential bias in sensitive modalities, requiring rigorous safeguards to prevent unauthorized access or misuse. Red-team coverage and contextual validation are vital for verifying reliability, ensuring multimodal outputs align with real-world constraints and expectations. Ethical design demands continuous auditing, fairness-aware training, and transparent mechanisms to address these challenges without compromising model performance.'),
#   (3,
#    '## Architectural and System-Level Challenges  \n\nIntegrating diverse modalities (text, audio, video) into a cohesive LLM architecture presents significant technical hurdles. Cross-modal grounding requires aligning semantic representations across modalities, often through techniques like cross-modal attention or shared embeddings, to ensure consistency in meaning. However, this process demands careful calibration to avoid hallucinations and maintain accuracy. System-level challenges include optimizing for computational efficiency and memory usage, as modalities vary in resource demands (e.g., audio may require higher processing power than text). Efficient quantization, pruning, or model compression is critical to balance performance and resource constraints. Additionally, agentic AI frameworks must ensure coordination and alignment between multi-agent systems, necessitating decentralized control and robust communication protocols to prevent conflicts in decision-making. These challenges underscore the need for adaptive architectures that can dynamically adjust to varying input modalities while maintaining ethical and operational integrity.'),
#   (4,
#    '## Performance and Cost Considerations  \nMultimodal LLMs require higher computational resources due to cross-modal processing, which demands significant GPU memory and tensor operations. Integrating text, images, audio, and video modalities increases the complexity of model architecture and training pipelines, leading to higher energy consumption and latency. Training costs scale with the number of modalities and the intricacy of integration, necessitating optimized data pipelines and efficient parallelism to manage computational demands.  \n\nOptimization techniques like quantization and pruning are critical for reducing latency and energy consumption. Quantization reduces model precision, lowering memory usage and inference speed, while pruning removes redundant parameters to minimize computational load. These strategies are essential for balancing performance and cost, particularly in resource-constrained environments. Ethical considerations, such as minimizing energy consumption, align with broader goals of sustainable AI development, ensuring that optimization efforts prioritize both efficiency and fairness.'),
#   (5,
#    '## Security and Privacy Frameworks  \nMultimodal Large Language Models (LLMs) must integrate robust privacy frameworks to comply with evolving regulations like GDPR and the EU AI Act. These frameworks must ensure data anonymization, differential privacy, and secure multi-party computation to protect sensitive information. Anonymization techniques, such as k-anonymity and data masking, are critical for preserving user privacy in multimodal systems, while differential privacy adds noise to training data to prevent re-identification. Emerging solutions like homomorphic encryption and federated learning enable privacy-preserving data processing without compromising model accuracy. These strategies are essential for maintaining trust in multimodal systems, particularly as data integration across modalities (e.g., text, images, audio) increases.'),
#   (6,
#    '## Debugging and Observability  \nDebugging and observability are critical for ensuring the reliability and ethical deployment of multimodal Large Language Models (LLMs). To address complex interactions between modalities, developers must implement logging and metrics to track input/output consistency, use distributed tracing for cross-modal pipeline monitoring, and leverage anomaly detection to identify hallucinations or bias in outputs.  \n\nLogging frameworks like Python’s `logging` or TensorBoard enable developers to record detailed traces of multimodal inputs (e.g., text, images, audio) and outputs, facilitating root-cause analysis. Metrics such as latency, error rates, and modal consistency scores can be monitored using tools like Prometheus or Datadog. For example, ensuring that image-caption alignment accuracy remains above 90% across diverse datasets is essential for reliable multimodal systems.  \n\nDistributed tracing, via tools like OpenTelemetry or Jaeger, allows tracing of requests across modalities, revealing bottlenecks or misalignments in cross-modal processing. This is particularly important when integrating models from different vendors or architectures, where pipeline interactions may introduce subtle errors.  \n\nAnomaly detection systems, such as those using machine learning models (e.g., TensorFlow’s anomaly detection layers), can identify hallucinations or unintended outputs by comparing generated responses to pre-trained benchmarks or ethical guidelines. This is critical for maintaining fairness and accuracy in applications like healthcare or legal AI, where biased or inconsistent outputs can have serious consequences.  \n\nBy combining these strategies, developers can build robust, ethically sound multimodal LLMs that are both observably reliable and aligned with regulatory and ethical frameworks.'),
#   (7,
#    '## Future Trends and Implications  \nThe integration of multimodal data will require evolving training paradigms and evaluation metrics. As models process text, images, audio, and video simultaneously, traditional supervised learning approaches will need to be reimagined. Training paradigms may shift toward **cross-modal alignment**—ensuring consistency across modalities—while evaluation metrics will expand to include **qualitative assessments** of coherence, contextual understanding, and modal interdependence. For example, a model might need to generate a textual description of an image while maintaining semantic alignment with the original data. This will demand **dynamic data handling** and **distributed training architectures** to manage the complexity of multimodal inputs.  \n\nEthical guidelines will continue to shape the development of multimodal systems. The **LLM Ethical Playbook (2026)** emphasizes the need for **transparency** in decision-making, **fairness** in cross-modal inference, and **accountability** for biases that may emerge in multimodal contexts. Ethical considerations in **LLM-induced hallucinations** (e.g., generating false information in healthcare scenarios) will drive the development of **runtime validation mechanisms** and **explainability frameworks**. These will ensure that multimodal systems respect user privacy, avoid harmful outputs, and align with societal values.  \n\nAdvancements in agentic AI will necessitate robust coordination and alignment mechanisms. The **Agentic AI and Multi-Agent Systems** YouTube video highlights the need for **shared goals**, **communication protocols**, and **coordination frameworks** to enable agents in multimodal systems to collaborate effectively. This will require **distributed reasoning** and **modal-specific adaptation** to handle the heterogeneous nature of multimodal data. For instance, a multimodal agent might need to negotiate between a text-based and image-based input to generate a coherent output. Such advancements will hinge on **modular architectures** and **dynamic resource allocation** to support complex, real-time interactions.'),
#   (8,
#    '## Conclusion  \nThe state of multimodal LLMs in 2026 is poised to evolve through a confluence of regulatory mandates, technical advancements, and ethical imperatives. Regulatory frameworks will increasingly dictate the design and deployment of multimodal models, emphasizing transparency, fairness, and data privacy. Technical challenges, such as model efficiency and real-time processing, will demand innovations in architecture, while ethical considerations will drive the development of robust prompt engineering and hallucination mitigation strategies. Continuous improvement in performance, security, and observability will be critical for real-world deployment, ensuring models align with operational feasibility and user trust. Balancing innovation with accountability will remain a cornerstone of progress, as the integration of multimodal capabilities into diverse applications—from healthcare to finance—requires rigorous validation and ethical oversight. The future of multimodal LLMs hinges on collaborative efforts to navigate these complexities, leveraging the provided evidence to guide responsible development and deployment.')],
#  'final': '# State of Multimodal LLMs in 2026: Ethical, Architectural, and Operational Considerations\n\n## Context and Ethical Foundations  \n\nThe development of multimodal Large Language Models (LLMs) in 2026 is increasingly shaped by regulatory frameworks and ethical priorities, with the EU AI Act (2024) and the US Executive Order 2026 setting critical benchmarks for transparency, bias mitigation, and data governance. The EU AI Act mandates that AI systems, including multimodal models, must include mechanisms to control bias, prevent hallucinations, and ensure data provenance, reflecting a global shift toward accountability in AI deployment. Meanwhile, the US Executive Order 2026 establishes a 2026 deadline for operator guidelines, emphasizing transparency in model behavior and the inclusion of red-team coverage to identify and mitigate vulnerabilities.  \n\nEthical frameworks such as the LLM Ethical Playbook highlight the necessity of operational rigor in addressing bias and hallucinations, emphasizing the importance of prompt engineering, data diversity, and continuous validation. These priorities underscore the growing recognition that multimodal LLMs must not only meet technical performance goals but also align with societal values, ensuring fairness, privacy, and trust in AI systems. As the field matures, the interplay between regulatory requirements and ethical design will continue to define the trajectory of multimodal LLMs in 2026.\n\n## Ethical Considerations in Multimodal LLMs  \nMultimodal large language models (LLMs) face critical ethical challenges, including bias, privacy, and hallucination mitigation. Bias control is essential to ensure equitable outcomes, as models may inherit biases from training data, leading to unfair results in sensitive modalities like healthcare or finance. Privacy frameworks must address data consent and potential bias in sensitive modalities, requiring rigorous safeguards to prevent unauthorized access or misuse. Red-team coverage and contextual validation are vital for verifying reliability, ensuring multimodal outputs align with real-world constraints and expectations. Ethical design demands continuous auditing, fairness-aware training, and transparent mechanisms to address these challenges without compromising model performance.\n\n## Architectural and System-Level Challenges  \n\nIntegrating diverse modalities (text, audio, video) into a cohesive LLM architecture presents significant technical hurdles. Cross-modal grounding requires aligning semantic representations across modalities, often through techniques like cross-modal attention or shared embeddings, to ensure consistency in meaning. However, this process demands careful calibration to avoid hallucinations and maintain accuracy. System-level challenges include optimizing for computational efficiency and memory usage, as modalities vary in resource demands (e.g., audio may require higher processing power than text). Efficient quantization, pruning, or model compression is critical to balance performance and resource constraints. Additionally, agentic AI frameworks must ensure coordination and alignment between multi-agent systems, necessitating decentralized control and robust communication protocols to prevent conflicts in decision-making. These challenges underscore the need for adaptive architectures that can dynamically adjust to varying input modalities while maintaining ethical and operational integrity.\n\n## Performance and Cost Considerations  \nMultimodal LLMs require higher computational resources due to cross-modal processing, which demands significant GPU memory and tensor operations. Integrating text, images, audio, and video modalities increases the complexity of model architecture and training pipelines, leading to higher energy consumption and latency. Training costs scale with the number of modalities and the intricacy of integration, necessitating optimized data pipelines and efficient parallelism to man ...
